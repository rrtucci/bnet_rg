# %% [markdown]
# # p0=None Efficiency Plots for Ising-like dynamical Bnet
#
# We plot the efficiency of our 2-dim Ising-like dynamical bnet for various temperatures and p0=None.
#
# p0=None means p0 is assigned at random for each node, from a uniform distribution from 0 to 1.

# %%
# this makes sure it starts looking for things from the Bayes_Petri_Net folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\bnet_rg

# %%
from  Net import *

# %% [markdown]
# # p0 = None

# %%
beta_jj = BETA_JJ_CURIE * 20
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 10

p0 = None
h=0
lam=0
net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.18554, av_eff=0.76524
# 2, mag=0.24774, av_eff=0.76798
# 3, mag=0.33445, av_eff=0.79772
# 4, mag=0.42453, av_eff=0.79534
# 5, mag=0.50800, av_eff=0.82030
# 6, mag=0.57217, av_eff=0.83849
# 7, mag=0.58195, av_eff=0.85266
# 8, mag=0.61312, av_eff=0.89266
# 9, mag=0.59852, av_eff=0.68148
# 10, mag=0.62429, av_eff=0.53414

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 3
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=-0.55366, av_eff=0.57708
# 2, mag=-0.68116, av_eff=0.60749
# 3, mag=-0.80505, av_eff=0.61364
# 4, mag=-0.89351, av_eff=0.57874
# 5, mag=-0.94875, av_eff=0.50112
# 6, mag=-0.98231, av_eff=0.41674
# 7, mag=-0.99092, av_eff=0.29930
# 8, mag=-0.99625, av_eff=0.21557
# 9, mag=-0.99695, av_eff=0.17982
# 10, mag=-0.99739, av_eff=0.14617
# 11, mag=-0.99744, av_eff=0.13919
# 12, mag=-0.99747, av_eff=0.13505
# 13, mag=-0.99748, av_eff=0.13439
# 14, mag=-0.99748, av_eff=0.13420
# 15, mag=-0.99748, av_eff=0.13475
# 16, mag=-0.99748, av_eff=0.13744
# 17, mag=-0.99748, av_eff=0.14897
# 18, mag=-0.99747, av_eff=0.19200
# 19, mag=-0.99746, av_eff=0.29851
# 20, mag=-0.99739, av_eff=0.43361

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 1
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.07140, av_eff=0.19106
# 2, mag=0.06634, av_eff=0.25315
# 3, mag=0.06095, av_eff=0.26065
# 4, mag=0.06022, av_eff=0.26214
# 5, mag=0.06176, av_eff=0.26259
# 6, mag=0.06236, av_eff=0.26268
# 7, mag=0.06625, av_eff=0.26266
# 8, mag=0.06729, av_eff=0.26260
# 9, mag=0.07218, av_eff=0.26248
# 10, mag=0.07336, av_eff=0.26237
# 11, mag=0.07885, av_eff=0.26222
# 12, mag=0.08007, av_eff=0.26207
# 13, mag=0.08602, av_eff=0.26188
# 14, mag=0.08722, av_eff=0.26169
# 15, mag=0.09359, av_eff=0.26147
# 16, mag=0.09471, av_eff=0.26125
# 17, mag=0.10148, av_eff=0.26099
# 18, mag=0.10246, av_eff=0.26073
# 19, mag=0.10958, av_eff=0.26042
# 20, mag=0.11036, av_eff=0.26011

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 0.5
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=-0.01991, av_eff=0.06325
# 2, mag=-0.00331, av_eff=0.09135
# 3, mag=0.00044, av_eff=0.09368
# 4, mag=0.00164, av_eff=0.09416
# 5, mag=0.00131, av_eff=0.09430
# 6, mag=0.00111, av_eff=0.09432
# 7, mag=0.00073, av_eff=0.09434
# 8, mag=0.00055, av_eff=0.09434
# 9, mag=0.00034, av_eff=0.09434
# 10, mag=0.00025, av_eff=0.09434
# 11, mag=0.00016, av_eff=0.09434
# 12, mag=0.00012, av_eff=0.09434
# 13, mag=0.00007, av_eff=0.09434
# 14, mag=0.00005, av_eff=0.09434
# 15, mag=0.00003, av_eff=0.09434
# 16, mag=0.00002, av_eff=0.09434
# 17, mag=0.00001, av_eff=0.09434
# 18, mag=0.00001, av_eff=0.09434
# 19, mag=0.00001, av_eff=0.09437
# 20, mag=0.00000, av_eff=0.09439
