# %% [markdown]
# # p0=None Efficiency Plots for Ising-like dynamical Bnet
#
# We plot the efficiency of our 2-dim Ising-like dynamical bnet for various temperatures and p0=None.
#
# p0=None means p0 is assigned at random for each node, from a uniform distribution from 0 to 1.

# %%
# this makes sure it starts looking for things from the Bayes_Petri_Net folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\bnet_rg

# %%
from  Net import *

# %% [markdown]
# # p0 = None

# %%
beta_jj = BETA_JJ_CURIE * 20
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 10

p0 = None
h=0
lam=0
net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.00401, av_eff=0.73346
# 2, mag=0.01393, av_eff=0.78230
# 3, mag=0.01121, av_eff=0.77690
# 4, mag=0.02210, av_eff=0.79567
# 5, mag=0.02866, av_eff=0.78516
# 6, mag=0.03612, av_eff=0.80794
# 7, mag=0.04862, av_eff=0.79348
# 8, mag=0.04984, av_eff=0.82190
# 9, mag=0.06492, av_eff=0.80535
# 10, mag=0.05910, av_eff=0.83576

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 3
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 19

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.14270, av_eff=0.59079
# 2, mag=0.20591, av_eff=0.62994
# 3, mag=0.28343, av_eff=0.62660
# 4, mag=0.36197, av_eff=0.62809
# 5, mag=0.45475, av_eff=0.62046
# 6, mag=0.51650, av_eff=0.59910
# 7, mag=0.59303, av_eff=0.58711
# 8, mag=0.60948, av_eff=0.51744
# 9, mag=0.66756, av_eff=0.47408
# 10, mag=0.66279, av_eff=0.41379
# 11, mag=0.71949, av_eff=0.36100
# 12, mag=0.72019, av_eff=0.36834
# 13, mag=0.77803, av_eff=0.31964
# 14, mag=0.79140, av_eff=0.35436
# 15, mag=0.84957, av_eff=0.30573
# 16, mag=0.87519, av_eff=0.33885
# 17, mag=0.92989, av_eff=0.28582
# 18, mag=0.95232, av_eff=0.30727
# 19, mag=0.98475, av_eff=0.24326

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 1
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.10169, av_eff=0.20507
# 2, mag=0.11445, av_eff=0.24906
# 3, mag=0.12235, av_eff=0.25590
# 4, mag=0.13127, av_eff=0.25819
# 5, mag=0.13641, av_eff=0.25927
# 6, mag=0.14471, av_eff=0.25965
# 7, mag=0.14927, av_eff=0.25984
# 8, mag=0.15778, av_eff=0.25977
# 9, mag=0.16233, av_eff=0.25967
# 10, mag=0.17126, av_eff=0.25941
# 11, mag=0.17591, av_eff=0.25918
# 12, mag=0.18526, av_eff=0.25882
# 13, mag=0.18999, av_eff=0.25848
# 14, mag=0.19971, av_eff=0.25806
# 15, mag=0.20446, av_eff=0.25766
# 16, mag=0.21449, av_eff=0.25718
# 17, mag=0.21921, av_eff=0.25676
# 18, mag=0.22947, av_eff=0.25621
# 19, mag=0.23411, av_eff=0.25575
# 20, mag=0.24451, av_eff=0.25518

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 0.5
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=-0.04660, av_eff=0.07094
# 2, mag=-0.02751, av_eff=0.09258
# 3, mag=-0.01675, av_eff=0.09396
# 4, mag=-0.01084, av_eff=0.09424
# 5, mag=-0.00708, av_eff=0.09430
# 6, mag=-0.00472, av_eff=0.09434
# 7, mag=-0.00315, av_eff=0.09434
# 8, mag=-0.00212, av_eff=0.09434
# 9, mag=-0.00142, av_eff=0.09434
# 10, mag=-0.00096, av_eff=0.09434
# 11, mag=-0.00064, av_eff=0.09434
# 12, mag=-0.00043, av_eff=0.09434
# 13, mag=-0.00029, av_eff=0.09434
# 14, mag=-0.00020, av_eff=0.09434
# 15, mag=-0.00013, av_eff=0.09434
# 16, mag=-0.00009, av_eff=0.09434
# 17, mag=-0.00006, av_eff=0.09434
# 18, mag=-0.00004, av_eff=0.09434
# 19, mag=-0.00003, av_eff=0.09439
# 20, mag=-0.00002, av_eff=0.09439
