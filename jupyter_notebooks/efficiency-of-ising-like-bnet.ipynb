# %% [markdown]
# # Efficiency of Ising-like dynamical Bnet
#
# We plot the efficiency of our 2-dim Ising-like dynamical bnet from various temperatures.

# %%
# this makes sure it starts looking for things from the Bayes_Petri_Net folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\bnet_rg

# %%
from  Net import *

# %%
beta_jj = BETA_JJ_CURIE * 5
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 6
net = Net(beta=beta, 
          jj=jj, 
          h=0, 
          lam=0, 
          num_iter=num_iter, 
          p0=.1,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.91839, av_eff=0.78018
# 2, mag=0.98197, av_eff=0.77435
# 3, mag=0.99677, av_eff=0.68553
# 4, mag=0.99967, av_eff=0.50122
# 5, mag=0.99991, av_eff=0.29917
# 6, mag=0.99994, av_eff=0.13186

# %%
# same as last one but smaller beta

beta_jj = BETA_JJ_CURIE * 3
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 15
net = Net(beta=beta, 
          jj=jj, 
          h=0, 
          lam=0, 
          num_iter=num_iter, 
          p0=.2,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.74040, av_eff=0.64192
# 2, mag=0.86961, av_eff=0.63431
# 3, mag=0.94771, av_eff=0.59890
# 4, mag=0.98237, av_eff=0.51078
# 5, mag=0.99299, av_eff=0.36819
# 6, mag=0.99629, av_eff=0.24562
# 7, mag=0.99713, av_eff=0.17645
# 8, mag=0.99739, av_eff=0.14655
# 9, mag=0.99745, av_eff=0.13764
# 10, mag=0.99747, av_eff=0.13492
# 11, mag=0.99748, av_eff=0.13422
# 12, mag=0.99748, av_eff=0.13399
# 13, mag=0.99748, av_eff=0.13398
# 14, mag=0.99748, av_eff=0.13394
# 15, mag=0.99748, av_eff=0.13394

# %%
# same as last one but smaller beta

beta_jj = BETA_JJ_CURIE * 1
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 20
net = Net(beta=beta, 
          jj=jj, 
          h=0, 
          lam=0, 
          num_iter=num_iter, 
          p0=.2,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.57119, av_eff=0.21936
# 2, mag=0.55758, av_eff=0.22076
# 3, mag=0.54810, av_eff=0.22151
# 4, mag=0.54165, av_eff=0.22205
# 5, mag=0.53642, av_eff=0.22276
# 6, mag=0.53234, av_eff=0.22340
# 7, mag=0.52875, av_eff=0.22405
# 8, mag=0.52578, av_eff=0.22464
# 9, mag=0.52309, av_eff=0.22515
# 10, mag=0.52081, av_eff=0.22558
# 11, mag=0.51872, av_eff=0.22599
# 12, mag=0.51694, av_eff=0.22634
# 13, mag=0.51530, av_eff=0.22666
# 14, mag=0.51390, av_eff=0.22691
# 15, mag=0.51260, av_eff=0.22717
# 16, mag=0.51149, av_eff=0.22736
# 17, mag=0.51047, av_eff=0.22755
# 18, mag=0.50960, av_eff=0.22772
# 19, mag=0.50885, av_eff=0.22784
# 20, mag=0.50846, av_eff=0.22778

# %%
# same as last one but smaller beta

beta_jj = BETA_JJ_CURIE * .5
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 20
net = Net(beta=beta, 
          jj=jj, 
          h=0, 
          lam=0, 
          num_iter=num_iter, 
          p0=.2,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.37095, av_eff=0.06716
# 2, mag=0.24032, av_eff=0.08355
# 3, mag=0.15845, av_eff=0.08966
# 4, mag=0.10557, av_eff=0.09226
# 5, mag=0.07067, av_eff=0.09342
# 6, mag=0.04745, av_eff=0.09390
# 7, mag=0.03190, av_eff=0.09416
# 8, mag=0.02146, av_eff=0.09428
# 9, mag=0.01445, av_eff=0.09430
# 10, mag=0.00973, av_eff=0.09432
# 11, mag=0.00655, av_eff=0.09434
# 12, mag=0.00441, av_eff=0.09434
# 13, mag=0.00297, av_eff=0.09434
# 14, mag=0.00200, av_eff=0.09434
# 15, mag=0.00135, av_eff=0.09434
# 16, mag=0.00091, av_eff=0.09434
# 17, mag=0.00061, av_eff=0.09434
# 18, mag=0.00041, av_eff=0.09430
# 19, mag=0.00028, av_eff=0.09420
# 20, mag=0.00019, av_eff=0.09377
