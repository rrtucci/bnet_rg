# %% [markdown]
# # p0=0.3 Efficiency Plots for Ising-like dynamical Bnet
#
# We plot the efficiency of our 2-dim Ising-like dynamical bnet for various temperatures and p0=0.3.

# %%
# this makes sure it starts looking for things from the Bayes_Petri_Net folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\bnet_rg

# %%
from  Net import *

# %% [markdown]
# # p0 = .3

# %%
beta_jj = BETA_JJ_CURIE * 20
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 6

p0 = .3
h=0
lam=0
net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.54112, av_eff=0.79720
# 2, mag=0.71139, av_eff=0.81087
# 3, mag=0.86599, av_eff=0.83196
# 4, mag=0.96278, av_eff=0.86727
# 5, mag=0.99368, av_eff=0.90474
# 6, mag=0.99968, av_eff=0.94041

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 3
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.52310, av_eff=0.64542
# 2, mag=0.67152, av_eff=0.64570
# 3, mag=0.81361, av_eff=0.63918
# 4, mag=0.91852, av_eff=0.61898
# 5, mag=0.97016, av_eff=0.55582
# 6, mag=0.98969, av_eff=0.42998
# 7, mag=0.99521, av_eff=0.29878
# 8, mag=0.99688, av_eff=0.20183
# 9, mag=0.99731, av_eff=0.15685
# 10, mag=0.99743, av_eff=0.14045
# 11, mag=0.99747, av_eff=0.13583
# 12, mag=0.99748, av_eff=0.13444
# 13, mag=0.99748, av_eff=0.13409
# 14, mag=0.99748, av_eff=0.13398
# 15, mag=0.99748, av_eff=0.13394
# 16, mag=0.99748, av_eff=0.13394
# 17, mag=0.99748, av_eff=0.13394
# 18, mag=0.99747, av_eff=0.13394
# 19, mag=0.99742, av_eff=0.13394
# 20, mag=0.99724, av_eff=0.13398

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 1
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.39118, av_eff=0.24681
# 2, mag=0.39298, av_eff=0.24622
# 3, mag=0.39742, av_eff=0.24524
# 4, mag=0.40358, av_eff=0.24418
# 5, mag=0.41007, av_eff=0.24319
# 6, mag=0.41679, av_eff=0.24224
# 7, mag=0.42323, av_eff=0.24134
# 8, mag=0.42951, av_eff=0.24048
# 9, mag=0.43536, av_eff=0.23968
# 10, mag=0.44095, av_eff=0.23890
# 11, mag=0.44609, av_eff=0.23815
# 12, mag=0.45096, av_eff=0.23749
# 13, mag=0.45541, av_eff=0.23681
# 14, mag=0.45959, av_eff=0.23620
# 15, mag=0.46338, av_eff=0.23560
# 16, mag=0.46693, av_eff=0.23505
# 17, mag=0.47013, av_eff=0.23457
# 18, mag=0.47312, av_eff=0.23409
# 19, mag=0.47578, av_eff=0.23366
# 20, mag=0.47815, av_eff=0.23335

# %%
# same as last one but smaller beta
beta_jj = BETA_JJ_CURIE * 0.5
jj = 1  # no jj dependence when h=0
beta = beta_jj / jj
num_iter = 20

net = Net(beta=beta, 
          jj=jj, 
          h=h, 
          lam=lam, 
          num_iter=num_iter, 
          p0=p0,
          do_reversing=False) #no change if do reversing
net.do_plot("test.txt")
# Out:
# 1, mag=0.24973, av_eff=0.08297
# 2, mag=0.16268, av_eff=0.08953
# 3, mag=0.10758, av_eff=0.09224
# 4, mag=0.07179, av_eff=0.09337
# 5, mag=0.04810, av_eff=0.09390
# 6, mag=0.03231, av_eff=0.09416
# 7, mag=0.02173, av_eff=0.09428
# 8, mag=0.01462, av_eff=0.09430
# 9, mag=0.00984, av_eff=0.09432
# 10, mag=0.00663, av_eff=0.09434
# 11, mag=0.00446, av_eff=0.09434
# 12, mag=0.00300, av_eff=0.09434
# 13, mag=0.00202, av_eff=0.09434
# 14, mag=0.00136, av_eff=0.09434
# 15, mag=0.00092, av_eff=0.09434
# 16, mag=0.00062, av_eff=0.09434
# 17, mag=0.00042, av_eff=0.09434
# 18, mag=0.00028, av_eff=0.09439
# 19, mag=0.00019, av_eff=0.09442
# 20, mag=0.00013, av_eff=0.09472
